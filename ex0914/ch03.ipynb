# %%
#가상환경 위치 확인
# !pip --version
# Out:
# pip 25.0.1 from D:\hanhwa0902\ex0914\.0914venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install dotenv

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

print(f"키값은:{os.environ["OPENAI_API_KEY"][:8]}")
# Out:
# 키값은:sk-proj-
